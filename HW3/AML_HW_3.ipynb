# %% [markdown]
# <b> MIS 382N: ADVANCED MACHINE LEARNING<b>
#
# Assignment 3
#
# Total points: 70
#
# Due: Monday, October 10 to be submitted via Canvas by 11:59 pm
#
# Your homework should be written in a python notebook. If you prefer, you can work in groups of two. **Please note that only one student per team needs to submit the assignment on Canvas but make sure to include both students' names and UT EIDs.**
#
# For any question that requires a handwritten solution, you may upload scanned images of your solution in the notebook or attach them to the assignment . You may write your solution using markdown as well.
#
# Please make sure your code runs and the graphs and figures are displayed in your notebook before submitting. (%matplotlib inline)

# %% [markdown]
# **This can be an individual assignment or group of 2. If you choose to do it as a group, please specify who you are working with (name and EID), then only one student should submit the homework. Put your name and eid here.**
#
# Name: Andrew Gillock
#
# EID: apg2255
#
# Name: Benjamin Kanarick
#
# EID: bjk2437

# %% [markdown]
# # Question 1: Tensorflow Playground (20 pts)
#
# In this question, you will be playing with [Tensorflow Playground](https://playground.tensorflow.org).
#
#
# Select "Classification" as the Problem Type. Among the four datasets shown in DATA, please select the top left dataset.
#
# Use the following settings as the DEFAULT settings for all subquestions: Learning rate = 0.03, Activation = Tanh, Regularization = None, Ratio of training to test data = 50%, Noise = 0, Batch Size = 30, input as  𝑋1  with  𝑋2 , One hidden layer with 4 neurons.
#
# a) (4 pts) Use the DEFAULT setting and run two experiments - one using Tanh as the activation function and one using the Linear activation function. Report the train, test losses for both at the end of 1000 epochs. What qualitative difference do you observe in the decision boundaries obtained? What do you think is the reason for this?
#
#
# We will now study the effect of certain variations in the network structure or training process, keeping all other aspects the same as in the DEFAULT setting specified above, with Tanh as the activation.
#
# b) (4 pts) Effect of number of hidden units: Keep other settings the same as in DEFAULT, report the training loss and test loss at the end of 1000 epochs using 2 neurons and 8 neurons in the hidden layer. What do you observe in terms of the decision boundary obtained as the number of neurons increases? What do you think is the reason for this?
#
# c) (4 pts) Effect of Learning rate and number of epochs: Keep other settings the same as in DEFAULT. For learning rate 10, 1, 0.1, 0.01 and 0.0001, report the train, test losses at the end of 100 epochs, 500 epochs and 1000 epochs respectively. What do you observe from the change of loss vs learning rate, and the change of loss vs epoch numbers? Also report your observations on the training and test loss curve (observe if you see noise for certain learning rates and reason why this is happening).
#
# d) (4 pts) Effect of the number of layers: Change your activation to ReLU and use a single hidden layer with 4 neurons and then add another hidden layer with 3 neurons and train both your models for 1000 epochs. Comments on your final models and decision boundaries and observe your training and test loss curves as well.
#
# d) (4 pts) Use the DEFAULT setting. Play around with any hyperparameters, network architectures or input features (such as  sin(𝑋1),𝑋21  etc.), and report the best train and test loss you obtain (test loss should be no greater than 0.06). Attach the screenshot showing your full network, output and the parameters. Briefly justify your results, and comment on what helps/what doesn't help with lowering the loss, etc.

# %% [markdown]
# # Answer
#
# ### Part a)
#
# #### Activiation Function: Tanh
#
# Test Loss after 1000 epochs: 0.022
# Training Loss after 1000 epochs: 0.011
#
#
#
# #### Activation Function: Linear
#
# Test Loss after 1000 epochs: 0.542
# Training Loss after 1000 epochs: 0.486
#
# It is evident that the decsision boundaries for the Tanh activation function are more circular and flexible in nature, whereas the linear boundaries are linear and not as flexible. Using a non-linear activiation function like Tanh, it is much easier for the model to generalize or adapt with a variety of data and can easily differienate between outputs. Using a linear function in this case where our data consists of an inner and outer classification is not the best function for data that needs to be classified in a non-linear manner.
#
# ### Part b)
#
# #### DEFAULT setting using 2 neurons in hidden layer:
#
# Test Loss: 0.294
# Training Loss: 0.181
#
# #### DEFAULT setting using 8 neurons in hidden layer:
#
# Test Loss: 0.015
# Training Loss: 0.007
#
# These results highlight the fact that a small number of neurons can produce underfitting in the model due to the fact that the network may not learn properly. On the other hand, having a high number of neurons in the model could lead to overfitting, indicating that there is always an intermediate amount of neurons that ensures proper training. We can think of each subsequent neuron as an additional variable in our model.
#
# #### Part c)
#
# ##### 100 epochs:
# Learning Rate 10: Test: 0.535 Train: 0.392 (Lots of noise in the test-loss curve)
#
# Learning Rate 1: Test: 0.285 Train: 0.163 (Lots of noise in the test-loss curve)
#
# Learning Rate 0.1: Test: 0.034 Train: 0.023
#
# Learning Rate 0.01: Test: 0.368 Train: 0.309
#
# Learning Rate 0.001: Test: 0.527 Train: 0.514
#
# ##### 500 epochs:
# Learning Rate 10: Test: 0.359 Train: 0.298 (Some noise in the test-loss curve)
#
# Learning Rate 1: Test: 0.279 Train: 0.149 (Lots of initial noise in the test-loss curve)
#
# Learning Rate 0.1: Test: 0.016 Train: 0.006
#
# Learning Rate 0.01: Test: 0.102 Train: 0.082
#
# Learning Rate 0.001: Test: 0.517 Train: 0.481
#
# ##### 1000 epochs:
# Learning Rate 10: Test: 0.205 Train: 0.136 (Some noise in the test-loss curve)
#
# Learning Rate 1: Test: 0.288 Train: 0.144 (Lots of initial noise in the test-loss curve)
#
# Learning Rate 0.1: Test: 0.011 Train: 0.003
#
# Learning Rate 0.01: Test: 0.043 Train: 0.032
#
# Learning Rate 0.001: Test: 0.478 Train: 0.437
#
# From these tests, we see the greatest loss when the epochs are low and the learning rate is high. We see the least amount of loss when the number of epochs are high and the learning rate is around 0.1 to 0.01. The number of epochs and learning rate act as tuning parameters for the network, which we can adjust to influence the loss values during testing.
#
#
# #### Part d)
#
# ##### ReLU model with one hidden layer
#
# Test Loss: 0.289
#
# Training Loss: 0.248
#
# ##### ReuLU model with two hidden layers
#
# Test Loss: 0.485
#
# Training Loss: 0.473
#
# #### Part e)
#
# We started off by the default settings and from prior parts of the problem we saw that the tanh activation was providing the best decision boundaries and therefore lowest loss scores. Once this was established, we then tried various combinations of inputs, hidden layers, and neurons per layers as well. The best model that produced the lowest loss on the data is shown below.
#
#     Learning rate: 0.01
#     Activation function: Tanh
#     Regularization: None
#     Number of epochs: 1,000
#     Inputs: X1 and X2
#     Number of hidden layers: 2
#     Neurons in 1st hidden layer: 5
#     Neurons in 2nd hidden layer: 2
#
# We beleive that having 2 hidden layers as well as a learning rate of 0.01 are the driving factors in the low test and training losses. We tried to replicate the input as close as possible and beleive the ouput we received is very close to the initial input.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 2 : t-SNE (7 pts)
#
# Read this [article](https://erdem.pl/2020/04/t-sne-clearly-explained) on t-SNE, a dimensionality reduction technique for visualization and explain it in your own words in one or two paragraphs.

# %% [markdown]
# #### Answer:
#
# t-distributed Stochastic Neighbor Embedding (t-SNE) is a dimensionality reduction technique similar to Principal Component Analysis (PCA). However, unlike PCA, t-SNE uses nonlinear dimensionality reduction to separate data that cannot be separated by a straight (linear) line. The algorithm works by first creating a probability distribution using a distance measurement. We can think of these similarity measurements as the conditional probability that a point in one cluster would belong to the same cluster as another data point. Given that clusters often have different variances, the algorithm uses a measurement known as perplexity, which gives a 'target' amount of neighbors for the data point being examined.
#
# Next, a low-dimensional space is created with the same number of data points as in the original space. To account for the crowding problem of Gaussian distributions, we use a Student t-distribution for its 'fatter' tails. This makes it easier to distiguish the y-value for each data point being represented in the distribution. Finally, Kullback-Leibler divergence is used between the conditional probabilities to optimize the t-SNE distribution. A gradient is calculated for each point and describes the strength of the 'pull' towards the centroid of each cluster.

# %% [markdown]
# # Question 3: PCA (8 pts)
#
# Explain the principle of Principal Component Analysis algorithm and in what sense is the selection of the eigenvectors to represent the data is an optimal choice.  How do you reconstruct (a noisy version of) the original data from the eigenvectors and the loadings?

# %% [markdown]
# # Answer:
#
# Principal Component Analysis 'PCA' is a method that is used to reduce the dimensions of a large set of data through transforming a set of variables in to a smaller set while also trying to keep as much information as possible from the original larger set. In other words, PCA attempts to retain as much information as possible with the fewest number of variables / dimensions. PCA is performed through obtaining / realizing the 'principle components' in the initial large data set and getting rid of all the other variables in which do not provide much relevance when conveying / obtaining as much information as possible.
#
# Eigenvectors in PCA can be thought of as the 'columns'/components in the data and each eigenvector provides and conveys information about the initial large data set. In order to optimally select the eigenvectors, we need to decide the fewest eigenvectors that portray and maintain the most data pertaining to the original set.
#
# In order to reconstruct a noisy version of the original data, we can multiply each principal component score by the transpose of the eigenvector matrix.

# %% [markdown]
# # Question 4: Outlier detection using PyOD (20 pts)
#
# Outlier detection, or anomaly detection is usually an unsupervised learning task where the objective is to identify suspicious observations in data. It has been widely used in military surveillance for enemy activities to prevent attacks, intrusion detection in cyber security, fraud detection for credit cards, etc.
#
# PyOD is a comprehensive and scalable Python library for detecting outlying objects in multivariate data. PyOD includes more than 30 detection algorithms and provides unified APIs which makes it quite handy to use. In this question, you will play with PyOD, explore three different outlier detection algorithms and compare their performances. First let's install PyOD.
#
# ```
# # install pyod using pip first
# !pip install pyod
# ```
#
# You can load the data stored in 'Q3_train_dataset.csv' and 'Q3_test_dataset.csv' using the following codes.
#
# ```
# import pandas as pd
# # Load data code goes here
# train_df = pd.read_csv('Q3_train_dataset.csv')
# test_df = pd.read_csv('Q3_test_dataset.csv')
#
# X_train = train_df[['X_train_0', 'X_train_1', 'X_train_2', 'X_train_3', 'X_train_4']].to_numpy()
# y_train = train_df[['y_train']].to_numpy()
# X_test = test_df[['X_test_0', 'X_test_1', 'X_test_2', 'X_test_3', 'X_test_4']].to_numpy()
# y_test = test_df[['y_test']].to_numpy()
# ```
#
#  `X_train` and `X_test` contain the features, with the dimension of 5. `y_train` and `y_test` store the outlier labels, 0 means normal data, 1 means outlier data.

# %%
import pandas as pd
# Load data code goes here
train_df = pd.read_csv('Q3_train_dataset.csv')
test_df = pd.read_csv('Q3_test_dataset.csv')

X_train = train_df[['X_train_0', 'X_train_1', 'X_train_2', 'X_train_3', 'X_train_4']].to_numpy()
y_train = train_df[['y_train']].to_numpy()
X_test = test_df[['X_test_0', 'X_test_1', 'X_test_2', 'X_test_3', 'X_test_4']].to_numpy()
y_test = test_df[['y_test']].to_numpy()

# %% [markdown]
# # Part a)
# **(5 pts)** **Fit `X_train` to a outlier detection model k Nearest Neighbors (kNN) using PyOD**, this [page](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.mcd) will provide some functions you may need.
#
# ```
# from pyod.models.knn import KNN
# clf = KNN() # initialize KNN class using the default parameters
#
# # YOUR CODE SHOULD COME HERE, FIT THE MODEL USING X_TRAIN
# ```
#
#
# **Use the fitted model to predict the outlier labels of `X_test`. Compute the raw outlier scores on `X_test` using `decision_function()`.**
#
# **Run PyOD's `evaluate_print()` function using the test set ground truth outlier labels and the raw outlier scores predicted by the model, to compute the ROC and Precision@n results .**
#
# ```
# from pyod.utils.data import evaluate_print
# ```

# %% [markdown]
# ### Part a code)

# %%
from pyod.models.knn import KNN

clf = KNN() # initialize KNN class using the default parameters

# fit the model using X_train
clf.fit(X_train)
# Out:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0)

# %%
from pyod.utils.data import evaluate_print

# predict the outlier labels of X_test using the trained model, compute the raw outlier scores on X_test using decision_function()
y_Decision_Function = clf.decision_function(X_test)

# then use evaluate_print() to print out the evaluation results
evaluate_print(clf, y_test, y_Decision_Function)
# Out:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0) ROC:0.9044, precision @ rank n:0.5

# %% [markdown]
# # Part b)
# **(5 pts)** `X_train` and `X_test` are 5-dimension features, which makes it impossible to visualize them in Euclidean plane. But we can use Principal Component Analysis (PCA) to reduce the dimensions of `X_train` and `X_test` to 2, and then plot them. You may want to use `fit_and_transform()` function.
#
#
# ```
# from sklearn.decomposition import PCA
#
# pca = PCA(n_components=2)
#
# # Fit pca to X_train and X_test and transform
# train_principalComponents = # IMPLEMENT
# test_principalComponents = # IMPLEMENT
# ```
#
# After reducing the dimension to 2, now you can visualize the outliers using PyOD's `visualize()` function. Please plot the visualization. You may find [this](https://pyod.readthedocs.io/en/latest/pyod.utils.html#module-pyod.utils.example) useful on how to use `visualize()` .
#
# ```
# from pyod.utils.example import visualize
# ```
#
# Now you should be able to observe the ground truth outliers and the outliers predicted by the model.

# %% [markdown]
# ### Part b code)

# %%
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings("ignore")

pca = PCA(n_components=2)

# Fit pca to X_train and X_test and transform 
train_principalComponents = pca.fit_transform(X_train)
test_principalComponents = pca.fit_transform(X_test)

#Predicted outliers
train_outliers = clf.predict(X_train)
test_outliers = clf.predict(X_test)

from pyod.utils.example import visualize

# Visualize the ground truth outliers and predicted outliers using visualize()
visualize(clf, train_principalComponents, y_train, test_principalComponents, y_test,train_outliers, test_outliers, show_figure = True)

# %% [markdown]
# # Part c)
# **(10 pts)** Apply the same process as in (a) and (b) to the following two models, and visualize the outlier results. Please compare the performance of the two models in terms of their ROC, Precision@n, and what you observe from the two visualizations.
#
# *   [Isolation-Based model - Isolation-based anomaly detection using Nearest-Neighbor Ensembles (INNE)](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.inne)
#
# ```
# from pyod.models.inne import INNE
# ```

# %% [markdown]
# ### Part c code)

# %%
from pyod.models.inne import INNE

inne = INNE()

inne.fit(X_train)

y_Decision_Function = inne.decision_function(X_test)

evaluate_print(inne, y_test, y_Decision_Function)
# Out:
# INNE(contamination=0.1, max_samples='auto', n_estimators=200,
#    random_state=None) ROC:0.8489, precision @ rank n:0.5

# %%
pca = PCA(n_components=2)

# Fit pca to X_train and X_test and transform 
train_principalComponents = pca.fit_transform(X_train)
test_principalComponents = pca.fit_transform(X_test)

#Predicted outliers
train_outliers = inne.predict(X_train)
test_outliers = inne.predict(X_test)

visualize(inne, train_principalComponents, y_train, test_principalComponents, y_test,train_outliers, test_outliers, show_figure = True)

# %% [markdown]
# Apply the same process as in (a) and (b) to the following two models, and visualize the outlier results. Please compare the performance of the two models in terms of their ROC, Precision@n, and what you observe from the two visualizations.

# %% [markdown]
# When comparing the KNN model with the INNE model, we can see that overall KNN is a slightly better classifier than INNE in this case. We know this because the ROC for KNN is 0.904, while the ROC for INNE is 0.849. The precision @n is equal for both models, suggesting they both achieve about 50% classification accuracy. When looking at the visualizations, the small discrepency between the two models is apparent. For KNN, we see a greater amount of data points classified correctly in both training and testing scenarios, while INNE did not perform as well in its classification predictions.

# %% [markdown]
# # Question 5: Pre-processing and sampling (15 pts)
#
# The following dataset contains House prices describing the sales of individual residential property in Ames, Iowa data with explanatory variables describing almost every aspect of residential homes and dependent variable being SalePrice. Here, some cells of most columns in the dataset contain NaN values.

# %%
import pandas as pd 
import numpy as np 
import scipy.stats as stats
import math
import matplotlib.pyplot as plt
np.random.seed(100)

data = pd.read_csv("sales_data.csv")
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Alley  OverallQual  OverallCond  \
# 0          60       RL         65.0     8450   NaN            7            5
# 1          20       RL         80.0     9600   NaN            6            8
# 2          60       RL         68.0    11250   NaN            7            5
# 3          70       RL         60.0     9550   NaN            7            5
# 4          60       RL         84.0    14260   NaN            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ... 3SsnPorch  ScreenPorch  PoolArea  \
# 0       2003          2003       196.0  ...         0            0         0
# 1       1976          1976         0.0  ...         0            0         0
# 2       2001          2002       162.0  ...         0            0         0
# 3       1915          1970         0.0  ...         0            0         0
# 4       2000          2000       350.0  ...         0            0         0
#
# ...

# %% [markdown]
# a)**(2 pts)**Print the number of NaN, NULL and empty values (combined sum) in each column.

# %%
data.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# MasVnrArea          8
# ExterQual           0
# BsmtFinSF1          0
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageCars          0
# GarageArea          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# ...

# %% [markdown]
# b)**(3 pts)**Create a copy of `data`, and name it `data_dm`, then create a new column in `data_dm` named `binned_garage_yr_built` and apply binning to the column `garage_yr_built`. Use `pandas.cut()` and modify its parameter list as below:
#
# ```
# bins=[1900, 1930, 1960, 1990, 2020]
# labels=['1900-1930', '1930-1960', '1960-1990', '1990-2020']
# include_lowest=True
# ```
# Next, perform one-hot encoding on this new column.

# %%
# create copy
data_dm = data.copy()

# create bins
data_dm['binned_garage_yr_built'] = pd.cut(data_dm['GarageYrBlt'], bins=[1900, 1930, 1960, 1990, 2020],
labels=['1900-1930', '1930-1960', '1960-1990', '1990-2020'],
include_lowest=True)

# one hot encoding
data_dm = pd.get_dummies(data_dm, columns = ['binned_garage_yr_built'], drop_first = True)

data_dm.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Alley  OverallQual  OverallCond  \
# 0          60       RL         65.0     8450   NaN            7            5
# 1          20       RL         80.0     9600   NaN            6            8
# 2          60       RL         68.0    11250   NaN            7            5
# 3          70       RL         60.0     9550   NaN            7            5
# 4          60       RL         84.0    14260   NaN            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ... PoolQC  Fence  MiscFeature  \
# 0       2003          2003       196.0  ...    NaN    NaN          NaN
# 1       1976          1976         0.0  ...    NaN    NaN          NaN
# 2       2001          2002       162.0  ...    NaN    NaN          NaN
# 3       1915          1970         0.0  ...    NaN    NaN          NaN
# 4       2000          2000       350.0  ...    NaN    NaN          NaN
#
#    MiscVal  MoSold YrSold SalePrice binned_garage_yr_built_1930-1960  \
# ...

# %% [markdown]
# c)**(3 pts)**Drop the columns which have more than 90%, 95% and 98% of missing values. List the columns which get dropped in each of the cases and observe the number of columns that get dropped in each of the cases as well.

# %%
# get % of missing values
percents = data.isnull().sum()/len(data)

# create masks
mask_90 = percents.values >= 0.9
mask_95 = percents.values >= 0.95
mask_98 = percents.values >= 0.98

# print columns > 90%
print('Above 90%: ')
print('Count: ', len(percents[mask_90]))
print(percents[mask_90])
print()

# print columnms > 95%
print('Above 95%: ')
print('Count: ', len(percents[mask_95]))
print(percents[mask_95])
print()

# print columns > 98%
print('Above 98%: ')
print('Count: ', len(percents[mask_98]))
print(percents[mask_98])
print()

# drop these columns
drops = percents[mask_90].index.tolist()
data = data.drop(drops, axis = 1)

data.head()
# Out:
# Above 90%:
# Count:  3
# Alley          0.937671
# PoolQC         0.995205
# MiscFeature    0.963014
# dtype: float64
#
# Above 95%:
# Count:  2
# PoolQC         0.995205
# MiscFeature    0.963014
# dtype: float64
#
# Above 98%:
# Count:  1
# PoolQC    0.995205
# dtype: float64
#    MSSubClass MSZoning  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0          60       RL         65.0     8450            7            5
# 1          20       RL         80.0     9600            6            8
# 2          60       RL         68.0    11250            7            5
# 3          70       RL         60.0     9550            7            5
# 4          60       RL         84.0    14260            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea ExterQual  ...  OpenPorchSF  \
# 0       2003          2003       196.0        Gd  ...           61
# 1       1976          1976         0.0        TA  ...            0
# ...

# %% [markdown]
# d)**(2 pts)**Take a sample of 800 rows at random and compute its mean. Compare the result with the population mean

# %%
np.random.seed(6)
sample_ages = np.random.choice(a= data['SalePrice'], size=800)

#Sample mean
print('Sample mean: ', sample_ages.mean())

#Population mean
print('Population mean: ', data.SalePrice.mean())
# Out:
# Sample mean:  178292.63125
# Population mean:  180921.19589041095

# %% [markdown]
# e) i)**(2pts)** Calculate 95% confidence intervals for SalePrice with a sample size of 100.
#
# ii)**(3pts)** Calculate 95 % confidence intervals for 100 different trials with a sample size of 500. Plot the confidence intervals and interpret how it captures the population mean.

# %%
np.random.seed(10)
sample_size = 100
sample = np.random.choice(a= data_dm['SalePrice'],
                          size = sample_size)
sample_mean = sample.mean()
pop_mean = data_dm.SalePrice.mean()

#Get the critical Z value, 1.96 corresponds to 95% CI
z_critical = 1.96

#Get population standard deviation
pop_stdev = data_dm.SalePrice.std()

#margin of error
margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size)) 

#confidence interval
confidence_interval = (sample_mean - margin_of_error,
                       sample_mean + margin_of_error)  
                       
#Print confidence interval and true mean value
print('95% Confidence Interval: ', confidence_interval)
print('True Mean: ', pop_mean)
# Out:
# 95% Confidence Interval:  (166521.7994349542, 197663.26056504578)
# True Mean:  180921.19589041095

# %%
np.random.seed(12)

#define the sample size
sample_size = 500

intervals = []
sample_means = []
pop_mean = data_dm.SalePrice.mean()

for sample in range(100):
    sample = np.random.choice(a= data_dm['SalePrice'], size = sample_size)
    sample_mean = sample.mean()
    sample_means.append(sample_mean)

    #compute z critical value
    z_critical = 1.96
    
    #compute population std dev        
    pop_stdev = data_dm.SalePrice.std()
    
    margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size))
    
    confidence_interval = (sample_mean - margin_of_error,
                           sample_mean + margin_of_error) 
    
    intervals.append(confidence_interval)


plt.figure(figsize=(13, 9))
plt.errorbar(x=np.arange(0.1, 100, 1),
             y=sample_means, 
             yerr=[(top-bot)/2 for bot,top in intervals],
             fmt='o')

plt.hlines(xmin=0, xmax=100,
           y=data['SalePrice'].mean(), 
           linewidth=2.0,
           color="red")
plt.title('Confidence Intervals for 100 Trials', fontsize = 20)
plt.show()

# %% [markdown]
# ### Solution:
#
# Each point on the graph represents the sample mean of a single trial out of one hundred. The margin of error for each sample was calculated by multiplying the standard error by the z-score value. Adding and subtracting this value from each sample mean gives us our 95% confidence interval. We can see in the graph that nearly every sample's confidence interval captures the true mean of the population (represented by the horizonal red line), except for 3 samples. This is not surprising given that calculating the 95% confidence interval means we are 95% confident that the true population mean lies within the interval. Although variation among each sample mean is relatively large, the confidence intervals gives us an idea of where the true mean is within the population.
